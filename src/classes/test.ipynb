# %%
from scryfall_classes import Data_Handling
from user_functions import User_Functions

# %%
dh = Data_Handling()
df = dh.cleaning_scryfall_data()
df.head()
# Out:
#                                      object  \
# oracle_id
# 0004ebd0-dfd6-4276-b4a6-de0003e94237   card
# 0006faf6-7a61-426c-9034-579f2cfcfa83   card
# 0007c283-5b7a-4c00-9ca1-b455c8dff8c3   card
# 000d5588-5a4c-434e-988d-396632ade42c   card
# 000e5d65-96c3-498b-bd01-72b1a1991850   card
#
#                                                                         id  \
# oracle_id
# 0004ebd0-dfd6-4276-b4a6-de0003e94237  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 0006faf6-7a61-426c-9034-579f2cfcfa83  7050735c-b232-47a6-a342-01795bfd0d46
# 0007c283-5b7a-4c00-9ca1-b455c8dff8c3  e718b21b-46d1-4844-985c-52745657b1ac
# 000d5588-5a4c-434e-988d-396632ade42c  036ef8c9-72ac-46ce-af07-83b79d736538
# 000e5d65-96c3-498b-bd01-72b1a1991850  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
#
#                                      multiverse_ids  mtgo_id  mtgo_foil_id  \
# oracle_id
# 0004ebd0-dfd6-4276-b4a6-de0003e94237        [15862]  15870.0       15871.0
# 0006faf6-7a61-426c-9034-579f2cfcfa83       [370780]  49283.0       49284.0
# 0007c283-5b7a-4c00-9ca1-b455c8dff8c3       [470580]  77122.0           NaN
# 000d5588-5a4c-434e-988d-396632ade42c        [83282]  22609.0       22610.0
# 000e5d65-96c3-498b-bd01-72b1a1991850        [12380]  12637.0       12638.0
#
#                                       tcgplayer_id  cardmarket_id  \
# oracle_id
# 0004ebd0-dfd6-4276-b4a6-de0003e94237        3094.0         3081.0
# 0006faf6-7a61-426c-9034-579f2cfcfa83       69965.0       262945.0
# 0007c283-5b7a-4c00-9ca1-b455c8dff8c3      196536.0       391692.0
# 000d5588-5a4c-434e-988d-396632ade42c       12835.0        12551.0
# 000e5d65-96c3-498b-bd01-72b1a1991850        6412.0        10604.0
#
#                                                      name lang released_at  \
# oracle_id
# 0004ebd0-dfd6-4276-b4a6-de0003e94237           Static Orb   en  2001-04-11
# 0006faf6-7a61-426c-9034-579f2cfcfa83  Sensory Deprivation   en  2013-07-19
# 0007c283-5b7a-4c00-9ca1-b455c8dff8c3       Road of Return   en  2019-08-23
# 000d5588-5a4c-434e-988d-396632ade42c           Storm Crow   en  2005-07-29
# 000e5d65-96c3-498b-bd01-72b1a1991850       Walking Sponge   en  1999-02-15
#
#                                       ... all_parts card_faces frame_effects  \
# oracle_id                             ...
# 0004ebd0-dfd6-4276-b4a6-de0003e94237  ...       NaN        NaN           NaN
# 0006faf6-7a61-426c-9034-579f2cfcfa83  ...       NaN        NaN           NaN
# 0007c283-5b7a-4c00-9ca1-b455c8dff8c3  ...       NaN        NaN           NaN
# 000d5588-5a4c-434e-988d-396632ade42c  ...       NaN        NaN           NaN
# 000e5d65-96c3-498b-bd01-72b1a1991850  ...       NaN        NaN           NaN
#
#                                       tcgplayer_etched_id promo_types loyalty  \
# oracle_id
# 0004ebd0-dfd6-4276-b4a6-de0003e94237                  NaN         NaN     NaN
# 0006faf6-7a61-426c-9034-579f2cfcfa83                  NaN         NaN     NaN
# 0007c283-5b7a-4c00-9ca1-b455c8dff8c3                  NaN         NaN     NaN
# 000d5588-5a4c-434e-988d-396632ade42c                  NaN         NaN     NaN
# 000e5d65-96c3-498b-bd01-72b1a1991850                  NaN         NaN     NaN
#
#                                      life_modifier  hand_modifier  \
# oracle_id
# 0004ebd0-dfd6-4276-b4a6-de0003e94237           NaN            NaN
# 0006faf6-7a61-426c-9034-579f2cfcfa83           NaN            NaN
# 0007c283-5b7a-4c00-9ca1-b455c8dff8c3           NaN            NaN
# 000d5588-5a4c-434e-988d-396632ade42c           NaN            NaN
# 000e5d65-96c3-498b-bd01-72b1a1991850           NaN            NaN
#
#                                      color_indicator content_warning
# oracle_id
# 0004ebd0-dfd6-4276-b4a6-de0003e94237             NaN             NaN
# 0006faf6-7a61-426c-9034-579f2cfcfa83             NaN             NaN
# 0007c283-5b7a-4c00-9ca1-b455c8dff8c3             NaN             NaN
# 000d5588-5a4c-434e-988d-396632ade42c             NaN             NaN
# 000e5d65-96c3-498b-bd01-72b1a1991850             NaN             NaN
#
# [5 rows x 77 columns]

# %%
import pickle
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def dummy_fun(doc):
    return doc

# %%
df = pd.read_csv(r'C:\Users\Alex Lucchesi\OneDrive\Documents\GitHub\MTG_app\src\data\oracle_data.csv')

# %%
vect = TfidfVectorizer(preprocessor= dummy_fun,
                       tokenizer= dummy_fun,
                       token_pattern=None)
vect.fit(df['lemmas'])
doc = vect.transform(df['lemmas'])
nn = NearestNeighbors(n_neighbors=10)
nn.fit(doc)
# Out:
# NearestNeighbors(n_neighbors=10)

# %%
doc = vect.transform(df['lemmas'][df['name'] == 'Blood on the Snow'])
n_index = nn.kneighbors(doc, n_neighbors=11, return_distance=False)

# %%
vocab = vect.vocabulary_
with open('vectorizer_vocab', 'wb') as f:
        pickle.dump(vocab, f)

# %%
with open('model', 'wb') as f:
        pickle.dump(nn, f)

# %%
for index in n_index[0][1:]:
    print(df['name'][index])
# Out:
# Surrakar Spellblade
# No Escape
# Rain of Riches
# Force of Negation
# Brutal Expulsion
# Wrexial, the Risen Deep
# Horobi's Whisper
# Syr Elenora, the Discerning
# Seize the Storm
# Kotose, the Silent Spider

# %%
"string.split(). if split.islower(): if split_string is not [list of stop words], uppercase them; else: if split string is [list of stop words]: lowercase the stopword"



stop_words = ['on', 'the']
cap_stop_words = [w.capitalize() for w in stop_words]
s = ''
card_name = 'Blood On the Snow'
split_name = card_name.split()

for name in split_name:
    if name[0].islower() and name not in stop_words:
        name = name.capitalize()
    elif name[0].isupper() and name in cap_stop_words:
        name = name.lower()
    s += (' ' +name)
    s = s.strip()
print(s)
# Out:
# Blood on the Snow
