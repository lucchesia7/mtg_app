# %%
import pandas as pd

# %%
tok = pd.read_csv(r'C:\Users\Alex Lucchesi\OneDrive\Documents\GitHub\MTG_app\src\data\token_data.csv')
c = pd.read_csv(r'C:\Users\Alex Lucchesi\OneDrive\Documents\GitHub\MTG_app\src\data\oracle_data.csv')
tok.head()
# Out:
#                               oracle_id object  \
# 0  0042a526-8828-40eb-bd32-4f57b230625a   card
# 1  0045c5fa-3229-4050-b139-5712fa24b308   card
# 2  005a8822-73ae-4953-9b46-a485e92df1b3   card
# 3  007e1815-b2ae-4861-b8c4-b0da8896d718   card
# 4  00bc99d9-2cc4-4dd5-a37b-4918fff8160a   card
#
#                                      id multiverse_ids  mtgo_id  mtgo_foil_id  \
# 0  21afb029-9aef-4e6e-a646-3343605b4bb7             []      NaN           NaN
# 1  548bf09e-1641-4d36-8e12-82b8708c4aae             []      NaN           NaN
# 2  caf28377-d831-4100-9843-d9f5db019791             []      NaN           NaN
# 3  364535a0-fa83-4e27-8cce-b38481b5eff1             []      NaN           NaN
# 4  f7d6c117-0924-404a-9b06-5c28b830d316             []      NaN           NaN
#
#    tcgplayer_id  cardmarket_id  \
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
#
# ...

# %%
c['image_uris'][c['name']=='Jorn, God of Winter']
# Out:
# Series([], Name: image_uris, dtype: object)

# %%
pd.options.display.max_colwidth = 9999

# %%
tok.columns
# Out:
# Index(['oracle_id', 'object', 'id', 'multiverse_ids', 'mtgo_id',
#        'mtgo_foil_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang',
#        'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image',
#        'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line',
#        'oracle_text', 'colors', 'color_identity', 'keywords', 'legalities',
#        'games', 'reserved', 'foil', 'nonfoil', 'finishes', 'oversized',
#        'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
#        'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
#        'rulings_uri', 'prints_search_uri', 'collector_number', 'digital',
#        'rarity', 'flavor_text', 'card_back_id', 'artist', 'artist_ids',
#        'illustration_id', 'border_color', 'frame', 'full_art', 'textless',
#        'booster', 'story_spotlight', 'edhrec_rank', 'prices', 'related_uris',
#        'security_stamp', 'preview', 'power', 'toughness', 'penny_rank',
# ...

# %%
import ast
counter=0
dl = tok[tok['name'].str.contains('//')]
dl.reset_index(inplace=True)
dual_face = dl[['card_faces', 'name']]
for k in dual_face['card_faces']:
    while counter < len(dual_face):
        s = ast.literal_eval(k)
        print(s[counter]['image_uris'])
#         counter+=1
# dd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 8
#       6 for k in dual_face:
#       7     while counter < len(dual_face):
# ----> 8         s = ast.literal_eval(k)
#       9         print(s[counter]['image_uris'])
#      10 #         counter+=1
#      11 # dd
#
# File C:\Program Files\Python310\lib\ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File C:\Program Files\Python310\lib\ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File C:\Program Files\Python310\lib\ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ...
